# %% [markdown]
# <a href="https://colab.research.google.com/github/ZANYANBU/Object-detection/blob/main/Experiment_1_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit

# %%
pip install qiskit-aer

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit (2,2)
qc.draw()
# Out:
#
# q_0:
#
# q_1:
#
# c: 2/

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
from qiskit.quantum_info import Statevector # Import the Statevector class

sim = Aer.get_backend('aer_simulator')
qc = QuantumCircuit(1) # Create a quantum circuit with one qubit
initial_state = [1,0] # Define initial_state as |1>
qc.initialize(initial_state, 0) # Apply initialisation operation to the 0th qubit
qc.save_statevector() # Tell simulator to save statevector

# The following line is changed:
# Instead of assembling the circuit before running it, we now pass the QuantumCircuit object directly to sim.run()
result = sim.run(qc).result()  # Do the simulation and return the result

# Assemble the circuit for later use if needed:
# qobj = assemble(qc) # Create a Qobj from the circuit for the simulator to run, if required for other purposes


out_state = result.get_statevector()
print(out_state) # Display the output state vector

qc.measure_all()
qc.draw()
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
#         ┌─────────────────┐ statevector  ░ ┌─┐
#      q: ┤ Initialize(1,0) ├──────░───────░─┤M├
#         └─────────────────┘      ░       ░ └╥┘
# meas: 1/════════════════════════════════════╩═
#                                             0

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
from qiskit.quantum_info import Statevector # Import the Statevector class

sim = Aer.get_backend('aer_simulator')
qc = QuantumCircuit(1) # Create a quantum circuit with one qubit
initial_state = [0,1] # Define initial_state as |1>
qc.initialize(initial_state, 0) # Apply initialisation operation to the 0th qubit
qc.save_statevector() # Tell simulator to save statevector

# Instead of assembling before running, run the circuit directly:
result = sim.run(qc).result()  # Do the simulation and return the result

# Assemble the circuit for later use if needed:
# qobj = assemble(qc) # Create a Qobj from the circuit for the simulator to run, if required for other purposes


out_state = result.get_statevector()
print(out_state) # Display the output state vector

qc.measure_all()
qc.draw()
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#         ┌─────────────────┐ statevector  ░ ┌─┐
#      q: ┤ Initialize(0,1) ├──────░───────░─┤M├
#         └─────────────────┘      ░       ░ └╥┘
# meas: 1/════════════════════════════════════╩═
#                                             0

# %%
pip install qiskit

# %%
pip install qiskit-aer

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
from qiskit.quantum_info import Statevector # Import the Statevector class

sim = Aer.get_backend('aer_simulator')
qc = QuantumCircuit(1) # Create a quantum circuit with one qubit
initial_state = [1,0] # Define initial_state as |1>
qc.initialize(initial_state, 0) # Apply initialisation operation to the 0th qubit
#qc.save_statevector() # Tell simulator to save statevector # This is removed as measure_all is called which implicitly calls save_statevector

# Instead of assembling before running, run the circuit directly:
#result = sim.run(qc).result()  # Do the simulation and return the result # This is removed as the next 2 lines do the assemble and run steps
# Assemble the circuit for later use if needed:
# qobj = assemble(qc) # Create a Qobj from the circuit for the simulator to run, if required for other purposes
# The line above to assemble is removed because sim.run expects a QuantumCircuit

qc.measure_all() # Measurement is added to the circuit
#qc.draw() # This is removed to avoid drawing before executing for histogram

# Now you can run the assembled qobj:
# result = sim.run(qobj).result() # This line is changed to pass the QuantumCircuit object 'qc' instead of 'qobj'
result = sim.run(qc).result() # Run the QuantumCircuit directly
counts = result.get_counts()
plot_histogram(counts)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
from qiskit.quantum_info import Statevector # Import the Statevector class

sim = Aer.get_backend('aer_simulator')
qc = QuantumCircuit(1) # Create a quantum circuit with one qubit
initial_state = [1,0] # Define initial_state as |1>
qc.initialize(initial_state, 0) # Apply initialisation operation to the 0th qubit
#qc.save_statevector() # Tell simulator to save statevector # This is removed as measure_all is called which implicitly calls save_statevector

# Instead of assembling before running, run the circuit directly:
#result = sim.run(qc).result()  # Do the simulation and return the result # This is removed as the next 2 lines do the assemble and run steps
# Assemble the circuit for later use if needed:
# qobj = assemble(qc) # Create a Qobj from the circuit for the simulator to run, if required for other purposes
# The line above to assemble is removed because sim.run expects a QuantumCircuit

qc.measure_all() # Measurement is added to the circuit
#qc.draw() # This is removed to avoid drawing before executing for histogram

# Now you can run the assembled qobj:
# result = sim.run(qobj).result() # This line is changed to pass the QuantumCircuit object 'qc' instead of 'qobj'
result = sim.run(qc).result() # Run the QuantumCircuit directly
counts = result.get_counts()
plot_histogram(counts)

# %%
initial_state = [1/sqrt(2), 1j/sqrt(2)] # Define state |q_0>
qc = QuantumCircuit(1) # Must redefine qc
qc.initialize(initial_state, 0) # Initialize the 0th qubit in the state `initial_state`
qc.save_statevector() # Save statevector

# The following line is changed. Instead of assembling and running again, we run with the existing qobj
#qobj = assemble(qc)
#state = sim.run(qobj).result().get_statevector() # Execute the circuit
state = sim.run(qc).result().get_statevector() # Execute the circuit using the QuantumCircuit object

print(state) # Print the result
#Statevector([0.57735027+0.j , 0. +0.81649658j],
#dims=(2))

# The following line is changed to run the QuantumCircuit instead of assembling and running again.
#qobj = assemble(qc)
results = sim.run(qc).result().get_counts()
plot_histogram(results)
# Out:
# Statevector([0.70710678+0.j        , 0.        +0.70710678j],
#             dims=(2,))

# %%
qc1=QuantumCircuit(1)
qc.initialize([1,0],0)
qc1.x(0)
qc1.save_statevector()
qc1.draw()
# Out:
#    ┌───┐ statevector
# q: ┤ X ├──────░──────
#    └───┘      ░

# %%
state1=sim.run(qc1).result().get_statevector()
print(state1)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
